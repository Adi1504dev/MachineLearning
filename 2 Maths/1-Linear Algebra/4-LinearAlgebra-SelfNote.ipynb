# %% [markdown]
# If We put zero vector we get zero becoz linear transformation do not move origin . Form there only rule of homogenity and Additivity is applied.
#
# Watch below
# any linear transformation moves unit vector to new point in such a way that origin remain at same place and grid lines are always parrallel .
# https://www.youtube.com/watch?v=kYB8IZa5AuE&list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab&index=3
# https://shad.io/MatVis/

# %% [markdown]
# ![image.png](attachment:image.png)
