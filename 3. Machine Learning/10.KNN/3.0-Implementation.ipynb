# %% [markdown]
# ### KNN

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_classification
X,y= make_classification(
    n_samples=10000,
    n_features=3,
    n_redundant=0,
    n_classes=2,
    random_state=999
)
X
# Out:
# array([[-0.15847321, -0.60140942, -0.71037508],
#        [ 0.26431194, -0.59809002, -0.08614094],
#        [ 3.00059796,  0.28124539, -0.14225347],
#        ...,
#        [-1.91697617,  1.89576238, -1.69792776],
#        [-0.93864015, -0.96724683, -1.02219322],
#        [ 0.38066028,  0.57925474,  0.88998795]], shape=(10000, 3))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5,algorithm='auto')
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_pred,y_test))
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# [[1490  212]
#  [ 161 1437]]
# 0.886969696969697
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      1702
#            1       0.87      0.90      0.89      1598
#
#     accuracy                           0.89      3300
#    macro avg       0.89      0.89      0.89      3300
# weighted avg       0.89      0.89      0.89      3300

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder,OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
pipeline=Pipeline([
    ('knn',KNeighborsClassifier())
])

param_grid = {
    'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'knn__weights': ['uniform','distance'],
    'knn__n_neighbors': [5,4,7,2,9] ,
    'knn__p': [1,2] ,

}

grid = GridSearchCV(
    pipeline,
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=3
)

grid.fit(X_train, y_train)

# %%
y_pred=grid.predict(X_test)
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_pred,y_test))
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# [[1502  226]
#  [ 149 1423]]
# 0.8863636363636364
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      1728
#            1       0.86      0.91      0.88      1572
#
#     accuracy                           0.89      3300
#    macro avg       0.89      0.89      0.89      3300
# weighted avg       0.89      0.89      0.89      3300
