# %% [markdown]
# ### Bag of words- Ngrams

# %%
import pandas as pd
df=pd.read_csv("data\SPAM_HAM_Data.txt")

# %%
df
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5569  spam  This is the 2nd time we have tried 2 contact u...
# 5570   ham               Will ü b going to esplanade fr home?
# 5571   ham  Pity, * was in mood for that. So...any other s...
# 5572   ham  The guy did some bitching but I acted like i'd...
# 5573   ham                         Rofl. Its true to its name
#
# [5574 rows x 2 columns]

# %%
import re
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
corpus=[]
stop_words = set(stopwords.words('english')) # do not craete it inside loop else will take too much time to run
for i in range(0,len(df)):
    review=re.sub("[^a-zA-Z]"," ",df['message'][i])
    review=review.split()
    review=[ps.stem(word) for word in review if word not in stop_words]
    corpus.append(' '.join(review))

# %%
# N-Grams
from sklearn.feature_extraction.text import CountVectorizer
#cv=CountVectorizer(max_features=2500) #Column=2500
cv=CountVectorizer(max_features=50,binary=True,ngram_range=(2,2)) #Column=50 #Keep up to 50 most frequent features.-- if unique words are less then it will be less
analyzer = cv.build_analyzer()

X=cv.fit_transform(corpus)

# %%
cv.vocabulary_ #It give vocab and its index
'''
(1,1)--> unigram
1,2--> uni and bi
2,2--> bi
2,3--> bi and tri
'''
# Out:
# {'to claim': np.int64(41),
#  'claim call': np.int64(7),
#  'free call': np.int64(15),
#  'chanc win': np.int64(6),
#  'let know': np.int64(25),
#  'we tri': np.int64(47),
#  'pleas call': np.int64(32),
#  'lt gt': np.int64(27),
#  'sorri call': np.int64(38),
#  'call later': np.int64(4),
#  'ur award': np.int64(43),
#  'custom servic': np.int64(11),
#  'po box': np.int64(33),
#  'tri contact': np.int64(42),
#  'prize guarante': np.int64(34),
#  'guarante call': np.int64(20),
#  'valid hr': np.int64(45),
#  'select receiv': np.int64(35),
#  'your account': np.int64(48),
#  'account statement': np.int64(0),
#  'identifi code': np.int64(22),
#  'urgent your': np.int64(44),
#  'your mobil': np.int64(49),
#  'call landlin': np.int64(3),
#  'wat time': np.int64(46),
#  'new year': np.int64(29),
#  'send stop': np.int64(37),
#  'co uk': np.int64(8),
#  'lt decim': np.int64(26),
#  'decim gt': np.int64(12),
#  'good morn': np.int64(17),
#  'good night': np.int64(18),
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Define your exact vocabulary with custom indices
my_vocab = {'machine': 0, 'learning': 1, 'nlp': 2}

# Initialize with the fixed vocabulary
cv = CountVectorizer(vocabulary=my_vocab) #fixed vocab
 #It give vocab and its index
X=cv.fit_transform(corpus)
cv.fixed_vocabulary_ #gives true in case of fixed vocab
# Out:
# True
