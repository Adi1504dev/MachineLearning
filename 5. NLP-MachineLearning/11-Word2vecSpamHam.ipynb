# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\hp\machinelearning\mlvenv\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hp\machinelearning\mlvenv\lib\site-packages (from gensim) (2.2.6)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\hp\machinelearning\mlvenv\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\hp\machinelearning\mlvenv\lib\site-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in c:\users\hp\machinelearning\mlvenv\lib\site-packages (from smart_open>=1.8.1->gensim) (2.2.1)

# %%
import pandas as pd
df=pd.read_csv("data\SPAM_HAM_Data.txt")

# %%
from nltk.stem import WordNetLemmatizer
import re
lemmitizer=WordNetLemmatizer()

# %%
corpus=[]
for i in range(0,len(df)):
    review=re.sub("[^a-zA-Z]"," ",df['message'][i])
    review=review.lower()
    review=review.split()
    review=[lemmitizer.lemmatize(word) for word in review]
    review=' '.join(review)
    corpus.append(review)

# %%
from nltk.tokenize import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words=[]
for sentence in corpus:
    sent_tokenize=sent_tokenize(sentence)
    for sent in 
    words.append(simple_preprocess(sentence))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 words=[]
#       2 for sentence in corpus:
# ----> 3     sent_tokenize=sent_tokenize(sentence)
#       4     words.append(simple_preprocess(sentence))
#
# TypeError: 'list' object is not callable
