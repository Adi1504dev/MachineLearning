# %% [markdown]
# ## Wordnet Lemmatizer
# Lemmatization technique is like stemming. The output we will get after lemmatization is called ‘lemma’, which is a root word rather than root stem, the output of stemming. After lemmatization, we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This class uses morphy() function to the WordNet CorpusReader class to find a lemma. Let us understand it with an example −

# %%
## Q&A,chatbots,text summarization
from nltk.stem import WordNetLemmatizer
import nltk

# %%
lemmatizer=WordNetLemmatizer()

# %%
'''
POS- Noun-n
verb-v
adjective-a
adverb-r
'''
nltk.download('wordnet')
lemmatizer.lemmatize("going",pos='v')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# 'go'

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
for word in words:
    print(word+"---->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eat
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->history
# finally---->finally
# finalized---->finalize

# %%
lemmatizer.lemmatize("goes",pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("fairly",pos='n'),lemmatizer.lemmatize("sportingly")
# Out:
# ('fairly', 'sportingly')

# %%
# !python -m spacy download en_core_web_sm
#If have spacy tar---> extract it and then set it path
#import spacy

#nlp = spacy.load(r"C:\models\en_core_web_sm")
#In nltk we set path but in spacy it is not like that u need to give complete model path
# Out:
# ...
#   Using cached en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#In real word no body uses nltk bcoz 
#U need to get token then---> pos tag can be get by nltk then map that tag with nltk tag--> then lemmitize
# people rather used spacy which does all autometically 
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("The cats are running")

for token in doc:
    print(token.text, token.pos_, token.lemma_)
# Out:
# The DET the
# cats NOUN cat
# are AUX be
# running VERB run
