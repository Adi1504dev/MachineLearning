# %% [markdown]
# #### Program
# It is sequence of instruction written in programing language.
#
# #### Process
# A process is simply an instance of a program that is being executed.---> Say we click chorme multiple time we will open multiple browsers . That means we are running multiple instance of chrome program.

# %% [markdown]
# Process in Details
#
# ![image.png](attachment:image.png)
# Code segment <br>
# Contains your code
#
# Data Segment<br>
# Contains your variable and data
#
# Heap<br>
# Dynamically allocation of memory will keep happening
#
# Stack<br>
# It makes sure it has access of local variables function call
#
# Register<br>
# Smaller memory --> to store variable method for small period of time

# %% [markdown]
# <li> Each process has seperate memory space se they do not corrupt each other
# <li> So they have Different IO requirement.

# %% [markdown]
# #### Thread
# Thread is unit of Execution within process
#
# <li> Single Threaded Application<br>
# EG: Paint --> Draw circle --> one thread will generate and will create circle and die
# Draw square --> one thread will generate and will create square and die
#
# ![image.png](attachment:image.png)
# <li> Multi Threaded Application-Stack and register for each thread is seperate rest is shared
#
# ![image-3.png](attachment:image-3.png)
