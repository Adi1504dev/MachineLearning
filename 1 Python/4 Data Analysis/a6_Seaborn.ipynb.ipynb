# %% [markdown]
# ### Seaborn
# Seaborn in python visualization library based on mathplot lib that provides high level interface for drawing attractive and informative statical graphics.  It helps in creating complex visualization with just a few line of code . In this lessom we will cover the basics of seaborn , including creating various types of plots and customizing them

# %% [markdown]
# #### Basic plotting

# %%
import seaborn as sns
#there are many internal data set in it
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### Create scatterplot

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("Total Bill vs tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip Amount")
plt.show()

# %% [markdown]
# #### Line plot

# %%
import matplotlib.pyplot as plt
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Total Bill by size")
# Out:
# Text(0.5, 1.0, 'Total Bill by size')

# %% [markdown]
# #### Categorical plot

# %% [markdown]
# ##### Bar Plot

# %%
import matplotlib.pyplot as plt
sns.barplot(x='day',y='total_bill',data=tips,estimator=sum)
plt.title("Total Bill by day")
# Out:
# Text(0.5, 1.0, 'Total Bill by day')

# %% [markdown]
# ##### Box Plot

# %%
import matplotlib.pyplot as plt
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title("Total Bill by day")
# Out:
# Text(0.5, 1.0, 'Total Bill by day')

# %% [markdown]
# ##### Violin plot

# %%
import matplotlib.pyplot as plt
sns.violinplot(x='day',y='total_bill',data=tips)
plt.title("Total Bill by day")
# Out:
# Text(0.5, 1.0, 'Total Bill by day')

# %% [markdown]
# ##### Histogram

# %%
import matplotlib.pyplot as plt
#both works
#sns.histplot(x='total_bill',bins=10 ,kde=True,data=tips)
sns.histplot(x=tips['total_bill'],bins=10 ,kde=True)
#kde true give line on histogram defining its shape
plt.title("Bill histogram")
# Out:
# Text(0.5, 1.0, 'Bill histogram')

# %% [markdown]
# ##### KDE plot

# %%
import matplotlib.pyplot as plt
sns.kdeplot(x=tips['total_bill'] ,fill=True)
#kde true give line on histogram defining its shape
plt.title("Bill histogram")
# Out:
# Text(0.5, 1.0, 'Bill histogram')

# %% [markdown]
# #### PairPlot

# %%
sns.pairplot(tips)
#It generates pair plot between all numerical values in data set

# %% [markdown]
# #### Heatmap

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Code	Input Type	Output Type	Dimensions
# df['Value']	String	Series	1D (Single column)
# df[['Value']]	List	DataFrame	2D (Single column in a table)
# df[['Value', 'Sales']]	List	DataFrame	2D (Multiple columns)

# %%
#While selecting cloumn we give double square so we can select 
#multiple columns as list

corr=tips[["total_bill","tip","size"]].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
from matplotlib.pyplot import annotate


sns.heatmap(corr,annot=True,cmap="coolwarm")
#annot To show value of co relation
# Out:
# <Axes: >

# %% [markdown]
# #### Custom visualization

# %%
import pandas


df=pandas.read_csv("sales_data_sample.csv")
df
# Out:
#    Order ID        Date Customer Name                 Product     Category  \
# 0      1001  2025-06-01  Anita Sharma         Apple iPhone 14  Electronics
# 1      1002  2025-06-01  Raj Malhotra        Noise Smartwatch      Fashion
# 2      1003  2025-06-02   Seema Yadav            Levi's Jeans     Clothing
# 3      1004  2025-06-02  Vikram Singh             Dell Laptop  Electronics
# 4      1005  2025-06-03  Preeti Mehra          Lakme Lipstick       Beauty
# 5      1006  2025-06-03  Suresh Kumar      Nike Running Shoes     Footwear
# 6      1007  2025-06-04  Kavita Joshi     Wooden Dining Table    Furniture
# 7      1008  2025-06-04    Amit Patel              HP Printer  Electronics
# 8      1009  2025-06-05  Ritika Gupta  Boat Bluetooth Speaker  Electronics
# 9      1010  2025-06-05   Anil Kapoor            Puma T-Shirt     Clothing
#
#    Quantity  Unit Price  Total
# 0         1       79900  79900
# 1         2        2999   5998
# 2         1        2999   2999
# ...

# %%
# In matplotlib we were aggregating and then creating plot but here 
# we have estimator argument which applies the aggregation on the fly
plt.figure(figsize=(10,8))
#default estimator mean--> estimator='mean'
sns.barplot(x=df["Category"],y=df["Total"],estimator='mean')# default is mean
# Out:
# <Axes: xlabel='Category', ylabel='Total'>
